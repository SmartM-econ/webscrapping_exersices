# %%
import requests as req
import bs4
#읽어 올 웹 주소
url = "https://www.datacamp.com/tracks/data-scientist-with-python/"
#읽어오기
res = req.get(url)
#읽어온 내용 출력
print(res.text)
# Out:
# <!DOCTYPE html><html><head><meta charSet="utf-8"/><meta http-equiv="x-ua-compatible" content="ie=edge"/><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"/><style data-href="https://static.datacamp.com/styles.b40a67d722ab86be20df.css">/*! normalize.css v3.0.2 | MIT License | git.io/normalize */.dc-tac-lg-tal{text-align:center}.dc-mobile__header-img-container{margin:0 -15px;text-align:center}.dc-center-lg-split,.dc-center-sm-split{margin:0 auto;text-align:center}.dc-mobile__fundamentals-text,.dc-mobile__practice-text{padding-top:32px}@media screen and (min-width:768px){.dc-center-sm-split{margin:0;text-align:left;width:50%}.dc-maxw-320_sm{max-width:320px}.dc-mobile__practice-text{order:1;padding-top:0}.dc-mobile__fundamentals-text{padding-top:0}.dc-mobile__practice-img{padding-right:48px}.dc-mobile__fundamentals-img{padding-left:48px}}@media screen and (min-width:1200px){.dc-tac-lg-tal{text-align:left}.dc-maxw-480_lg{max-width:480px}.dc-center-lg-split{margin:0;width:50%}.dc-mobile__header-content{align-items:center;display:flex}.dc-mobile__header-img-container{margin:16px 0 0;width:50%}.dc-mobile__practice-text{padding-right:48px}.dc-mobile__practice-img{order:1;padding-right:0;text-align:center}.dc-mobile__fundamentals-img{padding-left:0}.dc-mobile__fundamentals-text{order:1}}/*! normalize.css v3.0.2 | MIT License | git.io/normalize */.mobile-nav{position:absolute;overflow:visible}.mobile-nav .close{width:36px;height:36px;line-height:30px;font-size:2rem;top:0!important;right:0!important}.mobile-nav .close,.mobile-nav .close:focus,.mobile-nav .close:hover{background-color:transparent!important}.mobile-nav__container{margin:0 auto;width:100%}.mobile-nav__body{background-color:#fff;color:#4d5356;border-radius:4px;position:relative;box-shadow:0 15px 65px rgba(0,0,0,.5);width:calc(100% - 20px);float:none;margin:10px}.mobile-nav__item{padding-top:5px;padding-bottom:5px;margin-bottom:5px}.mobile-nav__item:last-child{padding-bottom:0;margin-bottom:0}.mobile-nav__create-account{width:100%;margin-bottom:15px}@media (min-width:480px){.mobile-nav__body{width:320px;margin:20px 15px;float:right}}@media (min-width:768px){.mobile-nav__container{width:750px}}.mobile-nav--ds-none{display:none!important}.mobile-nav--ds-block{display:block!important}@media (min-width:992px){.mobile-nav--ds-block{display:none!important}}/*! normalize.css v3.0.2 | MIT License | git.io/normalize */.dc-maxw-340{max-width:340px!important}.dc-navbar-search__input{background:hsla(0,0%,100%,.2)!important;border-color:transparent!important;box-sizing:border-box!important;color:#fff!important;flex-grow:1!important;padding:7px 35px!important;position:relative!important;-webkit-transition:all .3s cubic-bezier(.77,0,.175,1)!important;transition:all .3s cubic-bezier(.77,0,.175,1)!important}.dc-navbar-search__input::-webkit-input-placeholder{color:#fff!important;opacity:.8!important}.dc-navbar-search__input:-ms-input-placeholder{color:#fff!important;opacity:.8!important}.dc-navbar-search__input::-ms-input-placeholder{color:#fff!important;opacity:.8!important}.dc-navbar-search__input::placeholder{color:#fff!important;opacity:.8!important}.dc-navbar-search__input:focus{background-color:#fff!important;border-color:#fff!important;color:#3d4251!important;max-width:100%!important;z-index:50!important}.dc-navbar-search--solid-input .dc-navbar-search__input{background:#fff}.dc-navbar-search__icon{left:12px;position:absolute;top:12px;-webkit-transition:fill .3s cubic-bezier(.77,0,.175,1);transition:fill .3s cubic-bezier(.77,0,.175,1);z-index:1}.dc-navbar-search__input:focus+.dc-navbar-search__icon{fill:#859094;z-index:60}.dc-navbar-search__dropdown{left:0;position:absolute!important;right:0;top:calc(100% + 8px)!important;z-index:30;width:490px}.dc-navbar-search__item{border-top:1px solid #e6eaeb}.dc-navbar-search__technology{background-size:cover;flex-shrink:0;height:24px;margin-right:8px;width:24px}.dc-navbar-search__overlay{background:rgba(38,62,99, ...
#  * Bootstrap v3.3.5 (http://getbootstrap.com)
#  * Copyright 2011-2015 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
#  *//*!
#  * Generated using the Bootstrap Customizer (http://getbootstrap.com/customize/?id=016d6d5b48220591449a)
#  * Config saved to config.json and https://gist.github.com/016d6d5b48220591449a
#  *//*!
#  * Bootstrap v3.3.6 (http://getbootstrap.com)
#  * Copyright 2011-2015 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
#  *//*! normalize.css v3.0.3 | MIT License | github.com/necolas/normalize.css */[role=button]{cursor:pointer}.modal{display:none;overflow:hidden;position:fixed;top:0;right:0;bottom:0;left:0;z-index:1050;-webkit-overflow-scrolling:touch;outline:0}.modal .close{position:absolute;right:-25px;top:-25px;width:50px;height:50px;background:#3ac;-webkit-transition:background .25s ease;transition:background .25s ease;opacity:1;color:#fff;border-radius:50%;font-weight:300;z-index:1;font-size:1.5rem;border:0}.modal .close:focus,.modal .close:hover{text-decoration:none;cursor:pointer;background-color:#7ecce2}.modal-backdrop{position:fixed;top:0;right:0;bottom:0;left:0;z-index:1040;background-color:#000}.modal-backdrop.fade{opacity:0;filter:alpha(opacity=0)}.modal-backdrop.in{opacity:.5;filter:alpha(opacity=50)}.clearfix:after,.clearfix:before{content:" ";display:table}.clearfix:after{clear:both}.modal fieldset{width:100%}.modal-backdrop{background-color:#104a5b}.modal-backdrop.in{opacity:.8;filter:alpha(opacity=80)}/*! normalize.css v3.0.2 | MIT License | git.io/normalize */.dc-social-media,.dc-social-media__link{align-items:center;display:flex}.dc-social-media__link{border-bottom:0;font-weight:400;background:#3ac;border-radius:50%;color:#fff;height:48px;justify-content:center;text-align:center;width:48px}.dc-social-media__link:hover{border-bottom:0}.dc-social-media__link:not(:first-child){margin-left:16px}.dc-social-media__link:focus,.dc-social-media__link:hover{color:#263e63}.dc-social-media__link:focus .dc-icon,.dc-social-media__link:hover .dc-icon{fill:#263e63}/*! normalize.css v3.0.2 | MIT License | git.io/normalize *//*! normalize.css v3.0.2 | MIT License | git.io/normalize */.dc-btn{align-items:center;border:1px solid transparent;border-radius:4px;display:inline-flex;font-size:16px;-webkit-font-smoothing:antialiased;font-weight:700;justify-content:center;letter-spacing:inherit;padding:11px 15px;position:relative;text-align:center;-webkit-transition:background-color .3s cubic-bezier(.77,0,.175,1),border-color .3s cubic-bezier(.77,0,.175,1),color .3s cubic-bezier(.77,0,.175,1);transition:background-color .3s cubic-bezier(.77,0,.175,1),border-color .3s cubic-bezier(.77,0,.175,1),color .3s cubic-bezier(.77,0,.175,1);-webkit-user-select:none;-ms-user-select:none;user-select:none;white-space:nowrap}.dc-btn:active,.dc-btn:focus,.dc-btn:hover{border-color:transparent}.dc-btn:disabled{cursor:not-allowed;opacity:.25;-webkit-transition:opacity .3s cubic-bezier(.77,0,.175,1);transition:opacity .3s cubic-bezier(.77,0,.175,1)}.dc-btn:disabled:active,.dc-btn:disabled:focus,.dc-btn:disabled:hover{opacity:.25}.dc-btn--sm{padding:5px 15px}.dc-btn--lg{font-size:1.25rem;line-height:1.6;padding:15px 31px}.dc-btn--block{box-sizing:border-box;width:100%}.dc-btn--unstyled{background:0;border:0}.dc-btn--primary{background-color:#14243e;border-color:#14243e;color:#fff}.dc-btn--primary:active,.dc-btn--primary:focus,.dc-btn--primary:hover{background-color:#263e63;border-color:#263e63;color:#fff}.dc-btn--primary:disabled{background-color:#14243e;border-color:#14243e;color:#fff}.dc-btn--primary-light{background-color:#3ac;border-color:#3ac;color:#fff}.dc-btn--primary-light:active,.dc-btn--primary-light:focus,.dc-btn--primary-light:hover{background-color:#7ecce2;border-color:#7ecce2;color:#fff}.dc-btn--primary-light:disabled{background-color:#3ac;border-color:#3ac;color:#fff}.dc-btn--secondary{background-color:#ffc844;border-color:#ffc844;color:#3d4251}.dc-btn--secondary:active,.dc-btn--secondary:focus,.dc-btn--secondary:hover{background-color:#fbe28d;border-color:#fbe28d;color:#3d4251}.dc-btn--secondary:disabled{background-color:#ffc844;border-color:#ffc844;color:#3d4251}.dc-btn--tertiary{background-color:transparent;border-color:#7ecce2;color:#3d4251}.dc-btn--tertiary:active,.dc-btn--tertiary:focus,.dc-btn--tertiary:hover{border-color:#ffc844;color:#3d4251}.dc-btn--tertiary:disabled{background-color:transparent;border-color:#7ecce2;color:#3d4251}.dc-btn--green{b ...
# https://static.datacamp.com/static/bfe551166eba54f0696cfcb9be26862e/59d48/Data_Scientist.png 1.5x,
# https://static.datacamp.com/static/bfe551166eba54f0696cfcb9be26862e/59beb/Data_Scientist.png 2x" /><img loading="lazy" width="100" height="105" srcset="https://static.datacamp.com/static/bfe551166eba54f0696cfcb9be26862e/f1913/Data_Scientist.png 1x,
# https://static.datacamp.com/static/bfe551166eba54f0696cfcb9be26862e/59d48/Data_Scientist.png 1.5x,
# https://static.datacamp.com/static/bfe551166eba54f0696cfcb9be26862e/59beb/Data_Scientist.png 2x" src="https://static.datacamp.com/static/bfe551166eba54f0696cfcb9be26862e/f1913/Data_Scientist.png" alt="Project Illustration" style="position:absolute;top:0;left:0;opacity:1;width:100%;height:100%;object-fit:cover;object-position:center"/></picture></noscript></div></div><span class="dc-chapeau-title dc-u-color-secondary">Career <!-- -->Track</span><style data-emotion-css="l5634j">.css-l5634j{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#ffffff;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;font-size:2rem;margin-bottom:24px;margin-top:0;}</style><h1 class="css-l5634j">Data Scientist  with Python</h1><form action="/mobile_signup_flow" method="POST" class="dc-course-below-sm dc-u-pt-16"><p class="dc-input-group dc-u-mt-0 dc-u-mb-0"><span class="dc-input-group__icon"><span class="dc-icon dc-icon--white dc-icon--size-18 dc-icon--flex"><svg class="dc-icon__svg" width="18" height="18" viewBox="0 0 18 18"><g fill-rule="evenodd"><path d="M2.644 3.61c-.57 0-1.035.464-1.035 1.035v8.994c0 .571.465 1.035 1.035 1.035h12.648c.571 0 1.036-.464 1.036-1.035V4.645c0-.571-.465-1.035-1.035-1.035H2.645zm12.648 12.674H2.646A2.648 2.648 0 0 1 0 13.639V4.645A2.648 2.648 0 0 1 2.644 2h12.648a2.648 2.648 0 0 1 2.646 2.645v8.994a2.648 2.648 0 0 1-2.645 2.645z"></path><path d="M8.969 11.324a.804.804 0 0 1-.56-.226L.897 3.822a.804.804 0 1 1 1.12-1.156L8.968 9.4l6.952-6.734a.805.805 0 0 1 1.12 1.157l-7.513 7.276a.803.803 0 0 1-.56.226"></path><path d="M1.206 15.585a.805.805 0 0 1-.587-1.356l5.79-6.17A.804.804 0 1 1 7.583 9.16l-5.79 6.171a.802.802 0 0 1-.587.254M16.65 15.585a.804.804 0 0 1-.586-.252L10.588 9.52a.805.805 0 0 1 1.171-1.104l5.477 5.813a.805.805 0 0 1-.586 1.356"></path></g></svg></span></span><input type="text" placeholder="Email address" name="email" id="email" required="" class="dc-input-group__input dc-input--text dc-u-brad-br-0 dc-u-brad-tr-0"/><input type="submit" class="dc-btn dc-btn--secondary dc-u-brad-bl-0 dc-u-brad-tl-0" value="Start"/><input type="hidden" name="track_id" email="track_id" value="17"/></p></form><style data-emotion-css="syag5g">.css-syag5g{color:#ffffff;}</style><p class="css-syag5g">A Data Scientist combines statistical and machine learning techniques with Python programming to analyze and interpret complex data.</p><style data-emotion-css="1xrw9cf">.css-1xrw9cf{color:#ffffff;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;font-size:0.875rem;list-style:none;margin:0;padding:0;}@media screen and (min-width:1200px){.css-1xrw9cf{font-size:16px;}}</style><ul class="css-1xrw9cf"><style data-emotion-css="1huvyv1">.css-1huvyv1{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;margin-bottom:8px;}.css-1huvyv1:after{content:'|';display:inline-block;margin-left:16px;margin-right:15px;}.css-1huvyv1:last-of-type:after{content:'';}</style><li class="css-1huvyv1"><style data-emotion-css="1h6m16f">.css-1h6m16f{width:20px;height:20px;margin-right:8px;}</style><img src="data:image/svg+xml;base64,..." height="20" width="20" class="css-1h6m16f"/>Python</li><li class="css-1huvyv1"><span class="dc-icon dc-icon--secondary dc-icon--size-18 dc-u-mr-8 dc-icon--flex"><svg class="dc-icon__svg" width="18" height="18" viewBox="0 0 18 18"><path d="M8.35 9.689a.943.943 0 0 1-.278-.67V5.614a.946.946 0 1 1 1.893 0v2.46h2.082a.946.946 0 0 1 0 1.893H9.02a.943.943 0 0 1-.67-.277zM9 18A9 9 0 1 1 9 0a9 9 0 0 1 0 18zm0-1.837A7.163 7.163 0 1 0 9 1.837a7.163 7.163 0 0 0 0 14.326z" fill-rule="evenodd"></path></svg></span>100 hours</li><li class="css-1huvyv1"><span class="dc-icon dc-icon--secondary dc- ...
# https://static.datacamp.com/static/e40713a69926168fbf944b66c1695f17/c6f75/hugoaboutpic.jpg 1.5x,
# https://static.datacamp.com/static/e40713a69926168fbf944b66c1695f17/b5107/hugoaboutpic.jpg 2x" /><img loading="lazy" width="50" height="50" srcset="https://static.datacamp.com/static/e40713a69926168fbf944b66c1695f17/5cc7c/hugoaboutpic.jpg 1x,
# https://static.datacamp.com/static/e40713a69926168fbf944b66c1695f17/c6f75/hugoaboutpic.jpg 1.5x,
# https://static.datacamp.com/static/e40713a69926168fbf944b66c1695f17/b5107/hugoaboutpic.jpg 2x" src="https://static.datacamp.com/static/e40713a69926168fbf944b66c1695f17/5cc7c/hugoaboutpic.jpg" alt="Photo of Hugo Bowne-Anderson" style="position:absolute;top:0;left:0;opacity:1;width:100%;height:100%;object-fit:cover;object-position:center"/></picture></noscript></div><div><style data-emotion-css="1ogvh3l">.css-1ogvh3l{font-size:16px;margin-bottom:4px;text-transform:uppercase;}</style><h5 class="css-1ogvh3l">Hugo Bowne-Anderson</h5><style data-emotion-css="f85llx">.css-f85llx{margin:0;font-size:0.875rem;}</style><p class="css-f85llx">Data Scientist at DataCamp</p></div></footer></a></div></div><div class="css-1is6fqw"><div class="css-h5d9xd"><span class="css-ocvbo8">2</span></div><div class="css-2cldv8"><a href="/courses/intermediate-python-for-data-science" class="css-c6eu2x"><span class="css-11khr5q"><img alt="Python Icon" height="40" src="data:image/svg+xml;base64,..." width="40"/></span><div class="css-1hi4crg"><h4 class="css-1a7hu85">Intermediate Python</h4><p class="css-z6sjuf">Level up your data science skills by creating visualizations using Matplotlib and manipulating DataFrames with pandas.…</p><div class="css-4acvv2"><span class="css-4acvv2"><span class="dc-icon dc-icon--primary dc-icon--size-12 dc-u-mr-8 dc-icon--flex"><svg class="dc-icon__svg" width="18" height="18" viewBox="0 0 18 18"><path d="M8.35 9.689a.943.943 0 0 1-.278-.67V5.614a.946.946 0 1 1 1.893 0v2.46h2.082a.946.946 0 0 1 0 1.893H9.02a.943.943 0 0 1-.67-.277zM9 18A9 9 0 1 1 9 0a9 9 0 0 1 0 18zm0-1.837A7.163 7.163 0 1 0 9 1.837a7.163 7.163 0 0 0 0 14.326z" fill-rule="evenodd"></path></svg></span>4 hours</span></div></div><footer class="css-3guzbk"><div class="css-3xxt4t gatsby-image-wrapper" style="position:relative;overflow:hidden;display:inline-block;width:50px;height:50px"><img aria-hidden="true" src="data:image/jpeg;base64,..." alt="Photo of Filip Schouwenaars" style="position:absolute;top:0;left:0;width:100%;height:100%;object-fit:cover;object-position:center;opacity:1;transition-delay:500ms"/><noscript><picture><source srcset="https://static.datacamp.com/static/e57673425b18194f71e29408e7b31e13/5cc7c/Filipaboutpic.jpg 1x,
# https://static.datacamp.com/static/e57673425b18194f71e29408e7b31e13/c6f75/Filipaboutpic.jpg 1.5x,
# https://static.datacamp.com/static/e57673425b18194f71e29408e7b31e13/b5107/Filipaboutpic.jpg 2x" /><img loading="lazy" width="50" height="50" srcset="https://static.datacamp.com/static/e57673425b18194f71e29408e7b31e13/5cc7c/Filipaboutpic.jpg 1x,
# https://static.datacamp.com/static/e57673425b18194f71e29408e7b31e13/c6f75/Filipaboutpic.jpg 1.5x,
# https://static.datacamp.com/static/e57673425b18194f71e29408e7b31e13/b5107/Filipaboutpic.jpg 2x" src="https://static.datacamp.com/static/e57673425b18194f71e29408e7b31e13/5cc7c/Filipaboutpic.jpg" alt="Photo of Filip Schouwenaars" style="position:absolute;top:0;left:0;opacity:1;width:100%;height:100%;object-fit:cover;object-position:center"/></picture></noscript></div><div><h5 class="css-1ogvh3l">Filip Schouwenaars</h5><p class="css-f85llx">Data Science Instructor at DataCamp</p></div></footer></a></div></div><div class="css-1is6fqw"><style data-emotion-css="ppefao">.css-ppefao{display:none;border:7px solid #ebf4f7;background-color:#ffffff;border-radius:50%;height:56px;width:56px;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin-right:32px;}@media screen and (min-width:992px){.css-ppefao{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}}.css-ppefao:after{background-color:#e6eaeb;content:'';height:100%;position:absolute;width:1px;z-index:-1;top:45%;}.css-ppefao:after{height:0;}</style><div class="css-ppefao"><span class="css-ocvbo8">3</span></div><div class="css-2cldv8"><style data-emotion-css="v8p7ai">.css-v8p7ai{border:1px solid #e6eaeb;border-radius:4px;color:#4d5356;font-weight:400;margin-top:20px;max-width:100%;width:100%;position:relative;text-align:center;-webkit-transition:-webkit-transform 0.3s cubic-bezier(0.77,0,0.175,1);-webkit-transition:transform 0.3s cubic-bezier(0.77,0,0.175,1);transition:transform 0.3s cubic-bezier(0.77,0,0.175,1);}.css-v8p7ai:active,.css-v8p7ai:focus,.css-v8p7ai:hover{border-bottom-color:#e6eaeb;color:#4d5356;-webkit-transform:translate(0,-4px);-ms-transform:translate(0,-4px);transform:translate(0,-4px);z-index:10;}@media screen and (min-width:768px){.css-v8p7ai{max-width:100%;}}.css-v8p7ai:before{background-color:#ebf4f7;border-bottom:1px solid #e6eaeb;border-bottom-left-radius:4px;border-bottom-right-radius:4px;border-left:1px solid #e6eaeb;border-right:1px solid #e6eaeb;bottom:-13px;content:'';display:block;height:12px;left:50%;position:absolute;-webkit-transform:translateX(-50%);-ms-transform:translateX(-50%);transform:translateX(-50%);width:calc(100% - 48px);}.css-v8p7ai:after{background-color:#ebf4f7;border-bottom:1px solid #e6eaeb;border-bottom-left-radius:4px;border-bottom-right-radius:4px;border-left:1px solid #e6eaeb;border-right:1px solid #e6eaeb;bottom:-25px;content:'';display:block;height:12px;left:50%;position:absolute;-webkit-transform:translateX(-50%);-ms-transform:translateX(-50%);transform:translateX(-50%);width:calc(100% - 96px);}</style><a href="/courses/python-data-science-toolbox-part-1" class="css-v8p7ai"><span class="css-11khr5q"><img alt="Python Icon" height="40" src="data:image/svg+xml;base64,..." width="40"/></span><div class="css-1hi4crg"><h4 class="css-1a7hu85">Python Data Science Toolbox (Part 1)</h4><p class="css-z6sjuf">Learn the art of writing your own functions in Python, as well as key concepts like scoping and error handling.</p><div class="css-4acvv2"><span class="css-4acvv2"><span class="dc-icon dc-icon--primary dc-icon--size-12 dc-u-mr-8 dc-icon--flex"><svg class="dc-icon__svg" width="18" height="18" viewBox="0 0 18 18"><path d="M8.35 9.689a.943.943 0 0 1-.278-.67V5.614a.946.946 0 1 1 1.893 0v2.46h2.082a.946.946 0 0 1 0 1.893H9.02a.943.943 0 0 1-.67-.277zM9 18A9 9 0 1 1 9 0a9 9 0 0 1 0 18zm0-1.837A7.163 7.163 0 1 0 9 1.837a7.163 7.163 0 0 0 0 14.326z" fill-rule="evenodd"></path></svg></span>3 hours</span><button class="dc-btn dc-btn--unstyled dc-u-p-none" type="button"><span class="dc-icon dc-icon--primary dc-icon--size-12 dc-u-ml-24 dc-u-mr-8 dc-u-top-none"><svg class="dc-icon__svg" width="18" height="18" viewBox="0 0 18 18"><path d="M2.32 18A1.32 1.32 0 0 1 1 16.68V1.32A1.32 1.32 0 0 1 2.98.177l13.3 7.68a1.32 1.32 0 0 1 0 2.288l-13.3 7.679a1.32 1.32 0 0 1-.66.176zM3.64 3.61V14.39l9.33 ...
# https://static.datacamp.com/static/e40713a69926168fbf944b66c1695f17/c6f75/hugoaboutpic.jpg 1.5x,
# https://static.datacamp.com/static/e40713a69926168fbf944b66c1695f17/b5107/hugoaboutpic.jpg 2x" /><img loading="lazy" width="50" height="50" srcset="https://static.datacamp.com/static/e40713a69926168fbf944b66c1695f17/5cc7c/hugoaboutpic.jpg 1x,
# https://static.datacamp.com/static/e40713a69926168fbf944b66c1695f17/c6f75/hugoaboutpic.jpg 1.5x,
# https://static.datacamp.com/static/e40713a69926168fbf944b66c1695f17/b5107/hugoaboutpic.jpg 2x" src="https://static.datacamp.com/static/e40713a69926168fbf944b66c1695f17/5cc7c/hugoaboutpic.jpg" alt="Photo of Hugo Bowne-Anderson" style="position:absolute;top:0;left:0;opacity:1;width:100%;height:100%;object-fit:cover;object-position:center"/></picture></noscript></div><div><h5 class="css-1ogvh3l">Hugo Bowne-Anderson</h5><p class="css-f85llx">Data Scientist at DataCamp</p></div></footer></a></div></div><div class="dc-u-ta-center dc-u-pt-8"><button class="dc-btn dc-btn--tertiary dc-u-mv-32" type="button">See all <!-- -->26<!-- --> courses</button></div></div></div></div><style data-emotion-css="hiokh6">.css-hiokh6{border:1px solid #e6eaeb;border-radius:4px;margin:0 16px -32px;color:#4d5356;padding:16px;}@media screen and (min-width:768px){.css-hiokh6{margin:0 16px 64px;}}@media screen and (min-width:992px){.css-hiokh6{margin:68px 0 0;}}</style><div class="col-md-4 css-hiokh6"><style data-emotion-css="ky0ama">.css-ky0ama{text-transform:uppercase;color:#4d5356;padding:0;margin:0;font-weight:700;}</style><p class="css-ky0ama">Instructors</p><style data-emotion-css="odx3w6">.css-odx3w6{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding:12px 0px;border-bottom:none;-webkit-transition:-webkit-transform 0.3s cubic-bezier(0.77,0,0.175,1);-webkit-transition:transform 0.3s cubic-bezier(0.77,0,0.175,1);transition:transform 0.3s cubic-bezier(0.77,0,0.175,1);}.css-odx3w6:hover,.css-odx3w6:focus,.css-odx3w6:active{border-bottom:none;}.css-odx3w6:hover p,.css-odx3w6:hover h5{color:#33aacc;}</style><a href="/instructors/hugobowne" class="css-odx3w6"><style data-emotion-css="1sk7xa7">.css-1sk7xa7{border-radius:50%;border:0;min-width:50px !important;}</style><div class="dc-u-mr-12 css-1sk7xa7 gatsby-image-wrapper" style="position:relative;overflow:hidden;display:inline-block;width:50px;height:50px"><img aria-hidden="true" src="data:image/jpeg;base64,..." alt="Instructor Avatar" style="position:absolute;top:0;left:0;width:100%;height:100%;object-fit:cover;object-position:center;opacity:1;transition-delay:500ms"/><noscript><picture><source srcset="https://static.datacamp.com/static/e40713a69926168fbf944b66c1695f17/5cc7c/hugoaboutpic.jpg 1x,
# https://static.datacamp.com/static/e40713a69926168fbf944b66c1695f17/c6f75/hugoaboutpic.jpg 1.5x,
# https://static.datacamp.com/static/e40713a69926168fbf944b66c1695f17/b5107/hugoaboutpic.jpg 2x" /><img loading="lazy" width="50" height="50" srcset="https://static.datacamp.com/static/e40713a69926168fbf944b66c1695f17/5cc7c/hugoaboutpic.jpg 1x,
# https://static.datacamp.com/static/e40713a69926168fbf944b66c1695f17/c6f75/hugoaboutpic.jpg 1.5x,
# https://static.datacamp.com/static/e40713a69926168fbf944b66c1695f17/b5107/hugoaboutpic.jpg 2x" src="https://static.datacamp.com/static/e40713a69926168fbf944b66c1695f17/5cc7c/hugoaboutpic.jpg" alt="Instructor Avatar" style="position:absolute;top:0;left:0;opacity:1;width:100%;height:100%;object-fit:cover;object-position:center"/></picture></noscript></div><div class="dc-u-fx dc-u-fx-acc"><div><style data-emotion-css="azdl82">.css-azdl82{font-size:16px;color:#14243e;margin:0;}</style><h5 class="css-azdl82">Hugo Bowne-Anderson</h5><style data-emotion-css="304g6j">.css-304g6j{font-size:0.875rem;font-weight:400;color:#263e63;margin:0;}</style><p class="css-304g6j">Data Scientist at DataCamp</p></div></div></a><a href="/instructors/filipsch" class="css-odx3w6"><div class="dc-u-mr-12 css-1sk7xa7 gatsby-image-wrapper" style="position:relative;overflow:hidden;display:inline-block;width:50px;height:50px"><img aria-hidden="true" src="data:image/jpeg;base64,..." alt="Instructor Avatar" style="position:absolute;top:0;left:0;width:100%;height:100%;object-fit:cover;object-position:center;opacity:1;transition-delay:500ms"/><noscript><picture><source srcset="https://static.datacamp.com/static/e57673425b18194f71e29408e7b31e13/5cc7c/Filipaboutpic.jpg 1x,
# https://static.datacamp.com/static/e57673425b18194f71e29408e7b31e13/c6f75/Filipaboutpic.jpg 1.5x,
# https://static.datacamp.com/static/e57673425b18194f71e29408e7b31e13/b5107/Filipaboutpic.jpg 2x" /><img loading="lazy" width="50" height="50" srcset="https://static.datacamp.com/static/e57673425b18194f71e29408e7b31e13/5cc7c/Filipaboutpic.jpg 1x,
# https://static.datacamp.com/static/e57673425b18194f71e29408e7b31e13/c6f75/Filipaboutpic.jpg 1.5x,
# https://static.datacamp.com/static/e57673425b18194f71e29408e7b31e13/b5107/Filipaboutpic.jpg 2x" src="https://static.datacamp.com/static/e57673425b18194f71e29408e7b31e13/5cc7c/Filipaboutpic.jpg" alt="Instructor Avatar" style="position:absolute;top:0;left:0;opacity:1;width:100%;height:100%;object-fit:cover;object-position:center"/></picture></noscript></div><div class="dc-u-fx dc-u-fx-acc"><div><h5 class="css-azdl82">Filip Schouwenaars</h5><p class="css-304g6j">Data Science Instructor at DataCamp</p></div></div></a><a href="/instructors/dcheny" class="css-odx3w6"><div class="dc-u-mr-12 css-1sk7xa7 gatsby-image-wrapper" style="position:relative;overflow:hidden;display:inline-block;width:50px;height:51px"><img aria-hidden="true" src="data:image/png;base64,..." alt="Instructor Avatar" style="position:absolute;top:0;left:0;width:100%;height:100%;object-fit:cover;object-position:center;opacity:1;transition-delay:500ms"/><noscript><picture><source srcset="https://static.datacamp.com/static/4b1f33a42fb6b8aa61311f71f2906658/67a33/danielchen.png 1x,
# https://static.datacamp.com/static/4b1f33a42fb6b8aa61311f71f2906658/19787/danielchen.png 1.5x,
# https://static.datacamp.com/static/4b1f33a42fb6b8aa61311f71f2906658/f1913/danielchen.png 2x" /><img loading="lazy" width="50" height="51" srcset="https://static.datacamp.com/static/4b1f33a42fb6b8aa61311f71f2906658/67a33/danielchen.png 1x,
# https://static.datacamp.com/static/4b1f33a42fb6b8aa61311f71f2906658/19787/danielchen.png 1.5x,
# https://static.datacamp.com/static/4b1f33a42fb6b8aa61311f71f2906658/f1913/danielchen.png 2x" src="https://static.datacamp.com/static/4b1f33a42fb6b8aa61311f71f2906658/67a33/danielchen.png" alt="Instructor Avatar" style="position:absolute;top:0;left:0;opacity:1;width:100%;height:100%;object-fit:cover;object-position:center"/></picture></noscript></div><div class="dc-u-fx dc-u-fx-acc"><div><h5 class="css-azdl82">Daniel Chen</h5><p class="css-304g6j">Data Science Consultant at Lander Analytics</p></div></div></a><a class="dc-u-cursor-pointer">See all instructors</a></div></div><style data-emotion-css="1jlv85h">.css-1jlv85h{margin-bottom:-50px;padding-top:96px;text-align:left;}.css-1jlv85h + .footer{padding-top:154px;}@media screen and (min-width:768px){.css-1jlv85h{margin-top:-37px;margin-bottom:-133px;}.css-1jlv85h + .footer{padding-top:202px;}.css-1jlv85h.dc-course-below-sm + .footer{padding-top:64px;}}@media screen and (min-width:992px){.css-1jlv85h{margin-top:-26px;margin-bottom:-90px;}.css-1jlv85h + .footer{padding-top:154px;}}</style><article class="dc-u-pos-relative dc-u-z-100  css-1jlv85h"><div class="container"><div class="row"><style data-emotion-css="vw04eb">.css-vw04eb{background-image:linear-gradient(83deg,#2388b0,#33aacc);border-radius:4px;box-shadow:0 4px 8px 0 rgba(0,0,0,0.15);color:#ffffff;text-align:center;min-height:180px;padding:40px 16px 0;}@media screen and (min-width:768px){.css-vw04eb{margin:0 16px;padding:48px;}}@media screen and (min-width:992px){.css-vw04eb{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;padding:48px;text-align:left;}.css-vw04eb.dc-is-hidden{display:none;}}</style><div class="css-vw04eb"><style data-emotion-css="xbz9oe">.css-xbz9oe.dc-is-hidden{display:none;}@media screen and (min-width:992px){.css-xbz9oe{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;text-align:left;width:100%;}}</style><div class=" css-xbz9oe"><div><h1 class="dc-u-m-none dc-u-color-white">Ready To Learn?</h1><p class="dc-u-mb-0 dc-u-mt-8 ">Join <!-- -->5,340,000<!-- --> data science learners today!</p></div><div><style data-emotion-css="1223100">.css-1223100{margin:24px 0 -48px;}@media screen and (min-width:768px){.css-1223100{margin:24px 0 0 0;}}@media screen and (min-width:992px){.css-1223100{margin:0;}}</style><a class="dc-btn dc-btn--secondary dc-btn--lg  ds-snowplow-btn-home-footer-start-learning css-1223100" href="/users/sign_up?redirect=%2Ftracks%2Fdata-scientist-with-python%2Fenroll">Start Learning for Free</a></div></div><div class="dc-is-hidden css-xbz9oe"><div><h1 class="dc-u-m-none dc-u-color-white">Maximize Your Team’s Talent</h1><p class="dc-u-mb-0 dc-u-mt-8 ">Join 100s of businesses and create a culture of data at your company!</p></div><div><a class="dc-btn dc-btn--secondary dc-btn--lg dc-cta__btn ds-snowplow-btn-home-footer-see-business css-1223100" href="/groups/business#features">See all Business Features</a></div></div></div></div></div></article><footer class="footer"><div class="container footer__container clearfix"><div class="row"><div class="col-sm-6 col-md-2 dc-u-mb-48"><h3 class="footer__title chapeau-title">Learn</h3><ul class="footer__list"><li><a href="/learn/python">Python</a></li><li><a href="/learn/r-programming">R</a></li><li><a href="/learn/sql">SQL</a></li><li><a href="/courses">Courses</a></li><li><a href="/tracks/skill">Skill Tracks</a></li><li><a href="/tracks/career">Career Tracks</a></li><li><a href="/signal">Assessment</a></li></ul></div><div class="col-sm-6 col-md-2 dc-u-mb-48"><h3 class="footer__title chapeau-title" ...
#       p.GlobalSnowplowNamespace.push(i);p[i]=function(){(p[i].q=p[i].q||[]).push(arguments)
#       };p[i].q=p[i].q||[];n=l.createElement(o);g=l.getElementsByTagName(o)[0];n.async=1;
#       n.src=w;g.parentNode.insertBefore(n,g)}}(window,document,"script","//cdn.datacamp.com/sp/2.10.2.js","snowplow"));
#       </script><script src="https://script.tapfiliate.com/tapfiliate.js" type="text/javascript" async=""></script><script src="https://cdn.onesignal.com/sdks/OneSignalSDK.js" async=""></script><link rel="prefetch" href="/users/sign_up"/><script id="gatsby-script-loader">/*<![CDATA[*/window.pagePath="/tracks/data-scientist-with-python";/*]]>*/</script><script id="gatsby-chunk-mapping">/*<![CDATA[*/window.___chunkMapping={"app":["/app-cc456ee8d13001087c0d.js"],"component---src-templates-live-training-page-jsx":["/component---src-templates-live-training-page-jsx-177859fa9802c5f94152.js"],"component---src-templates-project-page-jsx":["/component---src-templates-project-page-jsx-d399b2c472225ff209e9.js"],"component---src-templates-user-story-page-jsx":["/component---src-templates-user-story-page-jsx-73070e5b3bf9f680b853.js"],"component---src-templates-course-page-jsx":["/component---src-templates-course-page-jsx-c58f8722fc04496ab169.js"],"component---src-templates-track-page-jsx":["/component---src-templates-track-page-jsx-cede02813bfc32e72d61.js"],"component---src-templates-instructor-page-jsx":["/component---src-templates-instructor-page-jsx-880bfd5b5e03ccf0e72c.js"],"component---src-pages-404-jsx":["/component---src-pages-404-jsx-c7cc86a848879ebeb84f.js"],"component---src-pages-about-index-jsx":["/component---src-pages-about-index-jsx-a444a27ad6d7194f5cc1.js"],"component---src-pages-about-leadership-jsx":["/component---src-pages-about-leadership-jsx-eb75359ac3a44be80821.js"],"component---src-pages-business-jsx":["/component---src-pages-business-jsx-8d9b2b279568e16b8e7b.js"],"component---src-pages-business-demo-jsx":["/component---src-pages-business-demo-jsx-6c2a626d5b3b8e2ee9bd.js"],"component---src-pages-careers-jsx":["/component---src-pages-careers-jsx-aa7e5160b1e89ef55987.js"],"component---src-pages-courses-jsx":["/component---src-pages-courses-jsx-b66fe8163f4d76220e15.js"],"component---src-pages-create-jsx":["/component---src-pages-create-jsx-0d6690103ccb3c8d405d.js"],"component---src-pages-github-students-jsx":["/component---src-pages-github-students-jsx-a4c263cb209bf8a4cae6.js"],"component---src-pages-groups-business-jsx":["/component---src-pages-groups-business-jsx-272ea24740ebcd046136.js"],"component---src-pages-groups-education-jsx":["/component---src-pages-groups-education-jsx-63ab8f4a2946e16e5901.js"],"component---src-pages-immersive-jsx":["/component---src-pages-immersive-jsx-02f46192534bf2daf5ae.js"],"component---src-pages-index-jsx":["/component---src-pages-index-jsx-2b4fba4429967ecd5167.js"],"component---src-pages-jobs-jsx":["/component---src-pages-jobs-jsx-2f64240fa431368ed023.js"],"component---src-pages-landing-1-jsx":["/component---src-pages-landing-1-jsx-f61621aad966816d4bb3.js"],"component---src-pages-landing-2-jsx":["/component---src-pages-landing-2-jsx-84267aa7e66bda349e99.js"],"component---src-pages-landing-3-jsx":["/component---src-pages-landing-3-jsx-9fedfd1986f9d0355597.js"],"component---src-pages-learn-python-with-anaconda-jsx":["/component---src-pages-learn-python-with-anaconda-jsx-3202b64582d91469b397.js"],"component---src-pages-learn-python-jsx":["/component---src-pages-learn-python-jsx-5e3876bf9ea7fcbbbb66.js"],"component---src-pages-learn-r-programming-jsx":["/component---src-pages-learn-r-programming-jsx-5a4c6f97aa5e3ed4ddb4.js"],"component---src-pages-learn-sql-jsx":["/component---src-pages-learn-sql-jsx-b94118cacf1be5f2301b.js"],"component---src-pages-mobile-jsx":["/component---src-pages-mobile-jsx-b56fa74416dda862efcb.js"],"component---src-pages-press-jsx":["/component---src-pages-press-jsx-0bd91f9c039a41c8276b.js"],"component---src-pages-privacy-policy-without-links-jsx":["/component---src-pages-privacy-policy-without-links-jsx-52422c175f3c0351cf1f.js"],"component---src-pages-privacy-policy-cookie-policy-jsx":["/component---src-pages-privacy-policy-cookie-policy-jsx-87965b30cb03d22f03f1.js"],"component---src-pages-privacy-policy-feedback-and-issues-jsx":["/component---src-pages-privacy-policy ...

# %%
#특정 요소(강좌) 검색
bs = bs4.BeautifulSoup(res.text,features="html.parser")

courses = bs.select("li.track__")
for c in courses:
    linkTag = c.select_one("a")
    if linkTag is None:
        break
    link = linkTag.attrs["href"]
    title = c.select_one("h4.course-block__title").getText().strip()
    desc = c.select_one("p.course-block__description").getText().strip()
    print(link,title,desc)

# %%
print(bs.select(".track__course"))
# Out:
# []
